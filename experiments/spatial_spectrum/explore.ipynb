# %% [markdown]
# # 同一连续 Fourier 初值的空间分辨率对照
# 只读分析入口。先显式填写已完成运行目录；不会选择最新结果或启动计算。

# %%
from pathlib import Path
import sys
root = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / "CONTEXT.md").exists())
sys.path.insert(0, str(root))
from experiments.common.analysis import analyze
RUNS = []  # 填写明确的运行目录
if RUNS:
    report = analyze(RUNS, name="spatial_spectrum")
    print(report)
else:
    print("请选择已完成运行；未执行分析或计算。")
